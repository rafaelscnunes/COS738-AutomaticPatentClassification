# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Aug 14 22:14:55 2017
@author: rodrigo
"""

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import operator as op

# %%
# Importing the dataset
#dataset = pd.read_csv('full.csv', delimiter='|')
#X = dataset.iloc[:, :-1].values
#y = dataset.iloc[:, 3].values

dataset = []
with open('full.csv', 'r', encoding="utf8") as file:
    for line in file:
        a = line.split('|')
        if len(a) == 7:
            dataset.append(a)
            
dataset = dataset[1:]

# %%
classes_count = {}
for data in dataset:
    classes = data[1].split(',')
    cl_set = set()
    for cl in classes:
        c = cl.upper()
        c = c.replace(' ', '')    
        try:
            cl_set.add(c[0])
        except:
            pass
    for i in list(cl_set):
        if i in classes_count:
            classes_count[i] += 1
        else:
            classes_count[i] = 1

sorted_keys, sorted_vals = zip(*sorted(classes_count.items(), key=op.itemgetter(0)))
plt.figure(figsize=(12,6))
sns.barplot(sorted_keys, sorted_vals, alpha=0.8)
plt.ylabel('Número de pedido de patentes', fontsize=12)
plt.xlabel('Classe de 1º nível', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

classes_count
# Out:
# {'0': 2,
#  '1': 2,
#  '2': 4,
#  '3': 2,
#  '4': 1,
#  '5': 1,
#  '7': 1,
#  '8': 5,
#  'A': 108928,
#  'B': 88195,
#  'C': 76804,
#  'D': 9608,
#  'E': 20504,
#  'F': 37294,
#  'G': 39754,
#  'H': 36135,
#  'I': 2,
#  'M': 1,
#  'N': 6,
#  'O': 1,
#  'P': 10,
#  'Q': 8,
#  'R': 1,
#  'S': 5,
#  'U': 2,
#  'É': 1}

# %%
n_classes_count = {}
for data in dataset:
    classes = data[1].split(',')
    if len(classes) in n_classes_count:
        n_classes_count[len(classes)] += 1
    else:
        n_classes_count[len(classes)] = 1

sorted_keys, sorted_vals = zip(*sorted(n_classes_count.items(), key=op.itemgetter(0)))
plt.figure(figsize=(12,6))
sns.barplot(sorted_keys, sorted_vals, alpha=0.8)
plt.ylabel('Número de pedido de patentes', fontsize=12)
plt.xlabel('Número de classes em todos os níveis', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

n_classes_count
# Out:
# {1: 194775,
#  2: 81908,
#  3: 36573,
#  4: 17304,
#  5: 8935,
#  6: 5528,
#  7: 2726,
#  8: 1881,
#  9: 1223,
#  10: 839,
#  11: 934,
#  12: 546,
#  13: 237,
#  14: 211,
#  15: 310,
#  16: 88,
#  17: 58,
#  18: 40,
#  19: 71,
#  20: 165,
#  21: 42,
#  22: 13,
#  23: 5,
#  24: 4,
#  25: 2,
#  27: 3,
#  28: 2,
#  29: 1,
#  30: 1,
#  32: 1,
#  34: 2,
#  35: 1,
#  38: 1,
#  39: 2,
#  42: 1,
#  83: 1}

# %%
n_classes_1_count = {}
for data in dataset:
    classes = data[1].split(',')
    cl_set = set()
    for cl in classes:
        c = cl.upper()
        c = c.replace(' ', '')    
        try:
            cl_set.add(c[0])
        except:
            pass
    if len(cl_set) in n_classes_1_count:
        n_classes_1_count[len(cl_set)] += 1
    else:
        n_classes_1_count[len(cl_set)] = 1
                              
sorted_keys, sorted_vals = zip(*sorted(n_classes_1_count.items(), key=op.itemgetter(0)))
plt.figure(figsize=(12,6))
sns.barplot(sorted_keys, sorted_vals, alpha=0.8)
plt.ylabel('Número de pedido de patentes', fontsize=12)
plt.xlabel('Número de classes de 1º nível', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

n_classes_1_count
# Out:
# {1: 295409, 2: 55378, 3: 3495, 4: 140, 5: 10, 7: 1, 10: 1}

# %%
# removido classes que nao estao entre A~H
classes_count = {}
for data in dataset:
    classes = data[1].split(',')
    cl_set = set()
    for cl in classes:
        c = cl.upper()
        c = c.replace(' ', '')    
        try:
            if c[0] in ['A','B','C','D','E','F','G','H']:
                cl_set.add(c[0])
        except:
            pass
    for i in list(cl_set):
        if i in classes_count:
            classes_count[i] += 1
        else:
            classes_count[i] = 1

sorted_keys, sorted_vals = zip(*sorted(classes_count.items(), key=op.itemgetter(0)))
plt.figure(figsize=(12,6))
sns.barplot(sorted_keys, sorted_vals, alpha=0.8)
plt.ylabel('Número de pedido de patentes', fontsize=12)
plt.xlabel('Classe de 1º nível', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

classes_count
# Out:
# {'A': 108928,
#  'B': 88195,
#  'C': 76804,
#  'D': 9608,
#  'E': 20504,
#  'F': 37294,
#  'G': 39754,
#  'H': 36135}

# %%
# removido classes que nao estao entre A~H
n_classes_1_count = {}
for data in dataset:
    classes = data[1].split(',')
    cl_set = set()
    for cl in classes:
        c = cl.upper()
        c = c.replace(' ', '')    
        try:
            if c[0] in ['A','B','C','D','E','F','G','H']:
                cl_set.add(c[0])
        except:
            pass
    if len(cl_set) != 0:
        if len(cl_set) in n_classes_1_count:
            n_classes_1_count[len(cl_set)] += 1
        else:
            n_classes_1_count[len(cl_set)] = 1
                              
sorted_keys, sorted_vals = zip(*sorted(n_classes_1_count.items(), key=op.itemgetter(0)))
plt.figure(figsize=(12,6))
sns.barplot(sorted_keys, sorted_vals, alpha=0.8)
plt.ylabel('Número de pedido de patentes', fontsize=12)
plt.xlabel('Número de classes de 1º nível', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

n_classes_1_count
# Out:
# {1: 295408, 2: 55381, 3: 3488, 4: 137, 5: 8}

# %%
import re

# removido classes que nao estao entre A~H
n_classes_count = {}
for data in dataset:
    classes = data[1].split(',')
    cl_set = set()
    for cl in classes:
        c = cl.upper()
        c = c.replace(' ', '')
        a = re.search(r'([A-H])([0-9]{2})', c, re.M|re.I)
        try:
            cl_set.add(a.group(1) + a.group(2))
        except:
            pass
    if len(cl_set) != 0:
        if len(cl_set) in n_classes_count:
            n_classes_count[len(cl_set)] += 1
        else:
            n_classes_count[len(cl_set)] = 1
                              
sorted_keys, sorted_vals = zip(*sorted(n_classes_count.items(), key=op.itemgetter(0)))
plt.figure(figsize=(12,6))
sns.barplot(sorted_keys, sorted_vals, alpha=0.8)
plt.ylabel('Número de pedido de patentes', fontsize=12)
plt.xlabel('Número de classes de 2º nível', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

n_classes_count
# Out:
# {1: 276658, 2: 65463, 3: 10117, 4: 1798, 5: 304, 6: 50, 7: 10, 8: 4}

# %%
# removido classes que nao estao entre A~H
classes_count = {}
for data in dataset:
    classes = data[1].split(',')
    cl_set = set()
    for cl in classes:
        c = cl.upper()
        c = c.replace(' ', '')
        a = re.search(r'([A-H])([0-9]{2})', c, re.M|re.I)
        try:
            cl_set.add(a.group(1) + a.group(2))
        except:
            pass
    for i in list(cl_set):
        if i in classes_count:
            classes_count[i] += 1
        else:
            classes_count[i] = 1

sorted_keys, sorted_vals = zip(*sorted(classes_count.items(), key=op.itemgetter(0)))
plt.figure(figsize=(12,6))
sns.barplot(sorted_keys, sorted_vals, alpha=0.8)
plt.ylabel('Número de pedido de patentes', fontsize=12)
plt.xlabel('Classe de 2º nível', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

print('Total: '+str(len(classes_count)))

classes_count
# Out:
# Total: 166
# {'A01': 17248,
#  'A04': 1,
#  'A07': 1,
#  'A21': 1217,
#  'A22': 767,
#  'A23': 7466,
#  'A24': 789,
#  'A27': 1,
#  'A41': 1736,
#  'A42': 470,
#  'A43': 1783,
#  'A44': 930,
#  'A45': 3108,
#  'A46': 1064,
#  'A47': 15083,
#  'A60': 1,
#  'A61': 56309,
#  'A62': 987,
#  'A63': 4652,
#  'A65': 1,
#  'A76': 1,
#  'A99': 2,
#  'B01': 9713,
#  'B02': 870,
#  'B03': 565,
#  'B04': 265,
#  'B05': 3163,
#  'B06': 71,
#  'B07': 554,
#  'B08': 663,
#  'B09': 354,
#  'B13': 1,
#  'B16': 1,
#  'B18': 1,
#  'B20': 2,
#  'B21': 2461,
#  'B22': 1850,
#  'B23': 3254,
#  'B24': 1126,
#  'B25': 1294,
#  'B26': 1263,
#  'B27': 1111,
#  'B28': 1053,
#  'B29': 5847,
#  'B30': 540,
#  'B31': 540,
#  'B32': 3421,
#  'B33': 1,
#  'B41': 2387,
#  'B42': 1847,
#  'B43': 753,
#  'B44': 731,
#  'B47': 1,
#  'B56': 1,
#  'B60': 15113,
#  'B61': 855,
#  'B62': 5479,
#  'B63': 1664,
#  'B64': 1538,
#  'B65': 20204,
#  'B66': 2014,
#  'B67': 1690,
#  'B68': 134,
#  'B69': 2,
#  'B81': 82,
# ...

# %%
# removido classes que nao estao entre A~H
classes_count = {}
for data in dataset:
    classes = data[1].split(',')
    cl_set = set()
    for cl in classes:
        c = cl.upper()
        c = c.replace(' ', '')
        a = re.search(r'([A-H])([0-9]{2})([A-Z])', c, re.M|re.I)
        try:
            cl_set.add(a.group(1) + a.group(2) + a.group(3))
        except:
            pass
    for i in list(cl_set):
        if i in classes_count:
            classes_count[i] += 1
        else:
            classes_count[i] = 1

sorted_keys, sorted_vals = zip(*sorted(classes_count.items(), key=op.itemgetter(0)))
plt.figure(figsize=(12,6))
sns.barplot(sorted_keys, sorted_vals, alpha=0.8)
plt.ylabel('Número de patentes', fontsize=12)
plt.xlabel('Classe de 3º nível', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

print('Total: '+str(len(classes_count)))

classes_count
# Out:
# Total: 759
# {'A01B': 1019,
#  'A01C': 1340,
#  'A01D': 1903,
#  'A01F': 503,
#  'A01G': 1231,
#  'A01H': 1286,
#  'A01J': 148,
#  'A01K': 2512,
#  'A01L': 48,
#  'A01M': 920,
#  'A01N': 6880,
#  'A01P': 717,
#  'A01S': 1,
#  'A01W': 1,
#  'A04B': 1,
#  'A07D': 1,
#  'A21B': 205,
#  'A21C': 451,
#  'A21D': 602,
#  'A21F': 1,
#  'A21G': 1,
#  'A21P': 1,
#  'A22B': 116,
#  'A22C': 668,
#  'A23B': 425,
#  'A23C': 720,
#  'A23D': 376,
#  'A23F': 299,
#  'A23G': 1065,
#  'A23J': 432,
#  'A23K': 1009,
#  'A23L': 4060,
#  'A23M': 2,
#  'A23N': 535,
#  'A23P': 382,
#  'A23R': 1,
#  'A24B': 262,
#  'A24C': 102,
#  'A24D': 220,
#  'A24F': 274,
#  'A27F': 1,
#  'A41B': 432,
#  'A41C': 162,
#  'A41D': 936,
#  'A41F': 75,
#  'A41G': 71,
#  'A41H': 114,
#  'A42B': 456,
#  'A42C': 14,
#  'A42D': 1,
#  'A42J': 2,
#  'A42L': 1,
#  'A43B': 1369,
#  'A43C': 107,
#  'A43D': 350,
#  'A43F': 1,
#  'A43H': 1,
#  'A43J': 1,
#  'A43L': 2,
#  'A44B': 612,
#  'A44C': 325,
#  'A45B': 169,
#  'A45C': 1112,
# ...

# %%
import re

# removido classes que nao estao entre A~H
n_classes_count = {}
for data in dataset:
    classes = data[1].split(',')
    cl_set = set()
    for cl in classes:
        c = cl.upper()
        c = c.replace(' ', '')
        a = re.search(r'([A-H])([0-9]{2})([A-Z])', c, re.M|re.I)
        try:
            cl_set.add(a.group(1) + a.group(2) + a.group(3))
        except:
            pass
    if len(cl_set) != 0:
        if len(cl_set) in n_classes_count:
            n_classes_count[len(cl_set)] += 1
        else:
            n_classes_count[len(cl_set)] = 1
                              
sorted_keys, sorted_vals = zip(*sorted(n_classes_count.items(), key=op.itemgetter(0)))
plt.figure(figsize=(12,6))
sns.barplot(sorted_keys, sorted_vals, alpha=0.8)
plt.ylabel('Número de pedido de patentes', fontsize=12)
plt.xlabel('Número de classes de 3º nível', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

n_classes_count
# Out:
# {1: 251820,
#  2: 73214,
#  3: 22847,
#  4: 4847,
#  5: 1221,
#  6: 320,
#  7: 87,
#  8: 18,
#  9: 13,
#  11: 2,
#  13: 1}

# %%
import re
# removido classes que nao estao entre A~H
classes_count = {}
for data in dataset:
    classes = data[1].split(',')
    cl_set = set()
    for cl in classes:
        c = cl.upper()
        c = c.replace(' ', '')
        a = re.search(r'(H)([0-9]{2})([A-Z])', c, re.M|re.I)
        try:
            cl_set.add(a.group(1) + a.group(2) + a.group(3))
        except:
            pass
    for i in list(cl_set):
        if i in classes_count:
            classes_count[i] += 1
        else:
            classes_count[i] = 1

sorted_keys, sorted_vals = zip(*sorted(classes_count.items(), key=op.itemgetter(0)))
plt.figure(figsize=(12,6))
sns.barplot(sorted_keys, sorted_vals, alpha=0.8)
plt.ylabel('Número de pedido de patentes', fontsize=12)
plt.xlabel('Classe de 3º nível', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

print('Total: '+str(len(classes_count)))

classes_count
# Out:
# Total: 57
# {'H01B': 844,
#  'H01C': 165,
#  'H01F': 713,
#  'H01G': 163,
#  'H01H': 1841,
#  'H01J': 379,
#  'H01K': 90,
#  'H01L': 926,
#  'H01M': 1377,
#  'H01P': 153,
#  'H01Q': 1038,
#  'H01R': 2471,
#  'H01S': 126,
#  'H01T': 280,
#  'H02B': 476,
#  'H02C': 1,
#  'H02G': 1330,
#  'H02H': 649,
#  'H02J': 955,
#  'H02K': 1747,
#  'H02M': 482,
#  'H02N': 269,
#  'H02P': 676,
#  'H02R': 1,
#  'H02S': 9,
#  'H02V': 1,
#  'H03B': 51,
#  'H03C': 29,
#  'H03D': 88,
#  'H03F': 207,
#  'H03G': 104,
#  'H03H': 126,
#  'H03J': 119,
#  'H03K': 299,
#  'H03L': 96,
#  'H03M': 461,
#  'H04B': 3585,
#  'H04D': 1,
#  'H04G': 1,
#  'H04H': 253,
#  'H04J': 836,
#  'H04K': 122,
#  'H04L': 4651,
#  'H04M': 2556,
#  'H04N': 3214,
#  'H04Q': 4267,
#  'H04R': 577,
#  'H04S': 72,
#  'H04W': 663,
#  'H05B': 1666,
#  'H05C': 58,
#  'H05F': 37,
#  'H05G': 29,
#  'H05H': 95,
#  'H05K': 1033,
#  'H61C': 1,
#  'H99Z': 2}
